# %% [markdown]
# <a href="https://colab.research.google.com/github/markiitya/Test/blob/main/openai_script_classify_spirit_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Установка библиотек

# %%
# !pip install openai pandas tqdm

# %%
import openai
import pandas as pd
from tqdm.auto import tqdm
import time
import json

# %% [markdown]
# ## API ключ

# %%
openai.api_key = "API ключ"

# %% [markdown]
# ## Промпт

# %%
prompt = """
Context: these texts are from the Shakespeare's plays.
Text ID:
1H4 — Henry IV, Part 1; 1H6 — Henry VI, Part 1; 2H4 — Henry IV, Part 2; 2H6 — Henry VI, Part 2; 3H6 — Henry VI, Part 3; AC — Antony and Cleopatra; AW — All's Well That Ends Well;
AYL — As You Like It; CE — The Comedy of Errors; Cor — Coriolanus; Cym — Cymbeline; H5 — Henry V; H8 — Henry VIII; Ham — Hamlet; JC — Julius Caesar; KJ — King John; KL — King Lear;
LLL — Love's Labour's Lost; MA — Much Ado About Nothing; MM — Measure for Measure; MND — A Midsummer Night's Dream; MV — The Merchant of Venice; MW — The Merry Wives of Windsor;
Mac — Macbeth; Oth — Othello; Per — Pericles, Prince of Tyre; R2 — Richard II; R3 — Richard III; RJ — Romeo and Juliet; TC — Troilus and Cressida; TGV — The Two Gentlemen of Verona;
TN — Twelfth Night; TNK — The Two Noble Kinsmen; TS — The Taming of the Shrew; Tem — The Tempest; Tim — Timon of Athens; Tit — Titus Andronicus; WT — The Winter's Tale.

Classify the word in the context by first identifying the subclass based on the most specific contextual meaning, then assign the main class (I–V) that the subclass belongs to.

Main Classes and Subclasses:

I.An animating or vital principle; the immaterial or sentient element of a person.

I.i.An animating or vital principle; the soul; incorporeal or immaterial being.

I.i.1.a.The animating or vital principle in humans and animals; that which gives life to the body, in contrast to its purely material being; the life force, the breath of life.

Examples:
- God made Adam, And his licham of erðe he nam, And blew ðor-in a liues blast,..A spirit ful of wit and sckil.
- Þet body of man is..þe vileste þet is, and þe spirit of man is þe zaule, and ys þe nobleste þing an þe heȝeste ssepþe þet may by.
- Who kneȝ, if the spirit [Latin spiritus] of the sonus of Adam steȝe vp aboue, and if the spirit [Latin spiritus] of bestis go doun bynethe?
- God..rypyth þe frutys of treis, and þe spyrytis alle of lyuyng thyngis be qwekynnyd.
- For euen as the bodie without the spirit is dead: so also faith without workes is dead.
- The spirit when it is gone foorth returneth not; neither the soule receiued vp, commeth againe.
- Least that pure breath of Life, the Spirit of Man.., cannot together perish With this corporeal Clod.
- Thus, a Man, tho' consisting of two very different Things, viz. Body and Spirit, is not two Persons.

I.i.1.b. In expressions indicating or implying that this principle has been diminished or has ceased, causing unconsciousness or death, or that it has recovered, causing consciousness or life to return.

Examples:
- Achior..fel in to his face vpon the erthe, and his lif quappide. After forsothe that, the spirit [Latin spiritu] taken aȝeen, he is reformed.
- And he seyinge thes thingis, sente out the spirit [a1425 L.V. ȝaf vp the goost; Latin exspiravit], ether diede.
- ‘Ne may Ich lenger libbe’..And wiþ þat word þe spirit out went.
- Neþerlesse þai may..moue almost to þe breþing out of þe spirit.
I.ii.4.a. Without article or possessive. Frequently with in
Examples:
- Huo þet is poure of ==spirit==, þet is of wylle, He ne zekþ..ne richesses.
- To whom forsoþe shal I beholden, no but to þe porelet & contrit in ==spirit==.
- And a..mayden thenkith what thingis ben of the Lord, that sche be hooly in body and ==spirit==.
- This rose of Iericho,..Pore in ==spirit==, parfit in pacyence.
- To mortifye his owne affectes and to set naught by himself, to abnegate and renownce his estimacion and glorye, to be renewed in ==spirit== and to folow christe mekely to dethe.
- The Captaine Generall was inwardly moued in ==spirit==.
- Losing more time by these dejections of ==spirit==.
- The poor Man had not ==Spirit== enough to discern what was best for him.
- Mr. Fleetwood felt an unusual elevation of ==spirit==.
- Saddened and humbled in ==spirit==, the young officer presented himself after a while to his old friends.


I.ii.4.b. With reference to a particular person. Chiefly with possessive adjective or genitive.

Examples:
- Sacrifise to God, [is] a ==spiritt== holly trublid.
- Nat may the woful ==spirit== in myn herte Declare a point of alle my sorwes smerte.
- The holy goste, That enspyres alle ==sperites==..to come to that blysse.
- My ==spirite== reioyseth in god my sauiour.
- They doe teach them to learne some art or occupation, according to the capacitie of their ==spirit==.
- As well in the fruites of the earth, as in the bodies and ==spirits== of men.
- But these low things bounded not their greate ==spiritts==.
- Should Fortune frown, live Thou serene, Nor let your ==Spirit== rise too high.
- That cordial thought her ==spirit== cheer's.
- They stood the trial of their ==spirits== without swerving from their allegiance.



I.ii.4.c. With the, with reference to human beings in general.

Examples:
- The soule in anguysshes, and the ==spirit== tormentid crieth to thee.
- Whan the ==spirit== hath take refeccioun in good odoures.
- Þi flesch, þat dispisith all werkis that þe ==spirite== lovith.
- Blesful is þat man whom..he calliþ fro teres to þe ioy of þe ==spirit==.
- Luther..hath offended in..not teaching those thinges, that are of the ==spirite==.
- As the Catholick ==Spirit== in Man applyes Each Sence and Organ, to their proper Ends.
- Saffron-posset-drink is very good against The heaviness of the ==Spirit==.
- Hopes..That cannot..cheer the ==spirit==, nor refresh the sight.
- Delights..That stir the ==spirit=='s inner deeps.



I.ii.6.a. Courage; boldness, assertiveness, mettle. Frequently in man (or woman) of spirit.

Examples:
- Þe herte of hem ys vnboundyn, & þer abood not in hem ==spirit== of hem dredynge þe entre of þe sonys of Irael.
- O blessyde Marie, what herte haddest þu, what ==spirit==, what strenkþe whanne þu vylle adoun..to-fore Crist.
- Seing Caratak of sa inuinsabyl ==sperit==.
- All furnisht al in Armes..As ful of ==spirit== as the month of May.
- She began the quarrell first: and what I do is but to right my wrong, as any other woman of ==spirit== would do.
- Molly had too much ==Spirit== to bear this Treatment tamely.
- Youths entering on the stage of life are catched with the engaging appellation, ‘a man of ==spirit==’.


I.ii.6.b. With with and (sometimes) modifying adjective, forming adverbial phrases with the sense ‘with boldness; vigorously, with gusto’.

Examples:
- After that D. Taylour thus with great ==spirite== and courage had aunswered for him selfe.
- Then may you well aduenture to trotte him [_sc._ your horse] in the same, making him doo it with ==spirite== and nimblenes.
- All things that are are with more ==spirit== chased then enioyd.
- They have..license from their Superiour, to be drunk.., to be better able to perform with more ==spirit== and vehemency their mad Dance.
- If the King would have acted with the ==spirit== that he sometimes put on, they might have carried their business.



I.ii.7. In plural.
I.ii.7.a. A person's mood or emotional state, esp. as liable to be depressed or lifted by events or circumstances. Frequently with qualifying adjective, esp. in adverbial phrases with in.

Examples:
- Þre harmes fallen of ire..movyng of ==spiritis== lettis oft men to herberow þo Holy Gost, þat lufs reste in soule.
- So feble eek were his ==spiritz== and so lowe..þt no man koude knowe His speche nor his voys.
- He..sumdeill affrayit wes; But in schort tym he till him tais His ==spiritis== richt full hardely.
- To visite his familie, and to recreate and refreshe his ==spirites== (as he openly sayde).
- Arden, cheere vp thy ==spirits== and droup no more.
- For we shall never brag That we have made his ==spirits== check at death.
- Sleep..Revivifies the Brain, the ==Spirits== chears.
- Dangers, the Sight of which, if discover'd to him, would..sink his ==Spirits==.

I.ii.8. In plural.
I.ii.8.a. Reflective or perceptive faculties; mental powers; senses, wits. Obsolete.

Examples:
- He fell down in swownyng..when he come vnto his ==spyrittis== agayn he went furth.
- That..thou gather to the thy ==spirites== and be..quyete.
- Neither can he recollect his ==spirits==,..that in prayer hee may..fixe his minde vpon God.
- Truly the more I scrue up my ==spirits== to reach it, the more I am swallowed in a gulf of admiration.
- To sing thy Praise, wou'd Heav'n my breath prolong, Infusing ==Spirits== worthy such a Song.

I.ii.8.b. A person's nature, character, or temperament. Cf. sense V.17a. Obsolete. rare.

Example:
- For what aduancement may I hope from thee That no reuenew hast but thy good ==spirits== To feede and clothe thee.

I.ii.9. The quality of being lively or animated; vivacity.
I.ii.9.a. figurative. Of a thing.

Examples:
- The small wynes, and those of little ==spirite== that quickly lose theyr strength.
- Spa water..has all the pertness of Champaigne, without its ==spirit==.

I.ii.9.b. Of a person, or his or her actions, speech, etc. Cf. sense I.ii.7b.

Examples:
- Yea, he often preached..with much ==spirit==, and unexpected vivacity, as a mighty man refreshed with the wine of the Spirit of God.
- An honest discourse, but pronounced, or rather read, without any ==Spirit== or seeming concerne.
- Arm'd with ==spirit==, wit, and satire.

II.An incorporeal, supernatural, rational being, and extended uses.
II.10.a. An incorporeal, supernatural, rational being, of a type usually regarded as imperceptible to humans but capable of becoming visible at will, and frequently (esp. in early use) conceived as terrifying, troublesome, or hostile to humankind. Often with modifying word or phrase indicating the nature or character of the being, or the context or environment with which it is associated. Often with the, denoting a particular being.

Examples:
- Þe lorde god of ==spirites== sent his aungel to þe prophetes.
- We haveþ i-lerned of Socrates, þat was alway tendaunt to a ==spirit== þat was i-cleped demon.
- Iesu..Was temptide with þe ==spirit== of wronge.
- We fynd writen..of suilk a maner of ==spirites==, bituex þe moyne & þe erth won.
- His wyf..sayd it was the fende or elles the goblyn or somme ==spyryte==.
- Þe ==sperytis== infernall, all þe hole rowte.
- Gabriell the ==spirit== of the Moone..begun his dominion ouer the world, the yeare of our Saviour his incarnation 1525.
- Giuing heed to seducing ==spirits==.
- Thow clepyst them aryght..The fadyr full of myght; The son, of wyt; the ==spyryt==, of goodnes.
- I saw the ==spirit== cummande doun as a dow fra heuen.
- Baptisme ye sacrament of birth of ye ==spirite==, as ye speake, in newe englyssh, and of the holly goost as the olde english turned it.
- If the ==Spirit== moves, he can disgorge himself against the Priests of Baal, the Hirelings.
- One of the ordinary Means, by which the ==Spirit== beareth witness in our favour, is the Word of God.

V.A guiding or governing principle or power, and related senses.
V.16.a. The active power of some emotion, disposition, motivation, etc., conceived as operating on or in a person in the manner of a possessing spirit (see sense II.10b).

In spirit of prophecy (compare quots. c1430, 1560), after post-classical Latin spiritus prophetiae (Vulgate), Hellenistic Greek τὸ πνεῦμα τῆς προφητείας (New Testament); in spirit of error (compare quot. 1551), after post-classical Latin spiritus erroris (Vulgate), Hellenistic Greek τὸ πνεῦμα τῆς πλάνης (New Testament). In instances in the Old Testament and Hebrew Scriptures after the corresponding use of Hebrew rūăḥ ruach n.

Examples:
- God ȝaf not to vs the ==spirit== of drede, but of vertu, and of loue, and sobrenesse.
- By a ==spirit== of prophecie..þey telleþ what me doþ in fer contrayes.
- Knowynge hym by the ==spirit== of prophecie.
- Hou shamfast shuld she be..forto speke with a ==spiryt== of ire.
- The Lorde hathe made Egypte droncken wyth the ==spirite== of erroure, and they shall vse it in all matters.
- One of them, as though he were moued with the ==spirite== of prophecie, runeth vp and downe the citie.
- O ==spirit== of Loue, how quicke and fresh art thou.
- The effectual power of the ==Spirit== of grace.
- The ==spirit== of lying runs away with more torrys than ever I had the honour to know.

V.16.b. With indefinite article. An impulse, tendency, inclination, etc., of a specified kind.

Examples:
- The Lord meddlid a ==spirit== of errour in the myddis therof.
- God send also..A ==spyrit== Of konnyng.
- A double ==spirit== Of teaching and of learning.
- God giveth not his children..valour, and then leaveth them to a ==spirit== of quarrelsomnesse.
- A ==spirit== of error is gone abroad, and many are carried off their feet therewith.
- I fear they wou'd ascribe the laying down my Paper, on such an occasion, to a ==Spirit== of Malcontentedness.
- A certain ==spirit== of improvement..has been promoted and carried on.

V.17.a. A particular (usually specified) character, disposition, or outlook existing in or animating a person or group of people. In later use often (with modifier) denoting the feeling of common purpose and camaraderie shared by a group; see community spirit, team spirit, etc.

Examples:
- Whan his herte was reyside vp, and his ==spirit== stablid to pride, he was putt doun of the seete of his rewme.
- Amongis grete men he was ful wel itawt, Amongis þe mene meke of ==spirith== & goost.
- Not onlye Moyses had the grace of gouerning.., but seuentie elders..had imparted vnto them of his ==spirite== and dignitie.
- He wisheth malicious..persons a better ==spirit==.
- There mette vs another youth of lesse yeeres, but no lesse gentle ==spirit==.
- Observing in his pupil a ==Spirit== fitted for the Government of that Monarchy.
- A dear friend (from whom I have often had the fair Idea and Character of your excellent ==Spirit==).
- His Person, his Port, and Behaviour, are suitable to a ==Spirit== of the highest Rank.

V.17.b. In adverbial phrases indicating the attitude, disposition, or frame of mind with which something is done, considered, or viewed.

Examples:
- He saw mene schynand be, & bot repofe to god seruand, of dedis gud & ==spyryt== schaldand.
- But rather, with good wyll, and glad ==spirite==: to be content with lesse than is nedefull.
- But from what ==spirit== these obiections proceede, may soone be gessed at.
- A perfect Judge will read each Work of Wit With the same ==Spirit== that its Author writ.

V.18.a. The essential character, nature, or qualities of something.

Examples:
- The trewe ==spirite== of the gospel.., whiche is sobre, mylde, & endewed with discrete symplicite.
- This kinde of gratitude..doth little auaile..to infuse the true ==spirit== of the worke into the Readers minde.
- The true ==Spirit== or Vein of ancient Poetry.
- Which is enough to support the ==Spirit== of Botany.


V.18.b. The defining character or mood of a particular period, esp. as reflected in the prevailing ideas, beliefs, and attitudes of the time.

Examples:
- The ==spirit== of the time shall teach me speed.
- They have also ordered Mr. John Smith, and Mr. Mungo Law, two of the bitterest spirited Ministers in Scotland, to go to Sterling to take charge of the Garison there, which speaks out the ==spirit== of the times.
- It seem'd the more reasonable to Digress, upon the Nature, and Character, and Fortune of the Duke; as being the best mirroir to discern the..==Spirit== of that Age.

V.18.c. Chiefly with the. The general intent or true meaning underlying a law, statement, etc., as opposed to its strict literal interpretation. Often contrasted or collocated with letter (see letter n.1 II.6, which antedates this sense by several centuries).

Examples:
- According to the known ==Spirit== of our Law, we can do no Injury to any Man entitled to Tythes, by obliging him to apply to an inferior Court.
- Knowing..that Magistrates are generally obliged to inflict penalties according to the Letter and not according to the ==Spirit== of an Act.
- His faith appears to have consisted in disbelieving the letter, almost as much as in believing the ==spirit== of the promise.

V.19. A person considered in relation to his or her character or disposition.
V.19.a. With modifying adjective.

Examples:
- Hereto would ye with slaughtred blood a noble ==spirite== stayne?
- Here I conuerse with those diuiner ==spirits==, Whose knowledge, and admire the world inherits.
- Many lively ==spirits== at length are most pittifully turned away from their forward course.
- Thus impossible it is to please froward ==spirits==.
- The Brave ==Spirits== of France now strive to vindicate their Liberty in Religious Matters.

Word:
{word}

Text:
{text}

Output format:
Json object with fields "thinking" and "result". Field "thinking" should contain all your intermediate reasoning. Field "result" should contain the final result - the value of corresponding main class (e.g. I, II, III, IV, V).



IMPORTANT:
DO NOT ADD ANY ADDITIONAL COMMENTS OR INTRODUCTIONS.
"""

# %%
import unicodedata

def clean_prompt(text):
    text = unicodedata.normalize('NFKD', text)
    text = text.encode('ascii', 'ignore').decode('ascii')
    return text

safe_prompt = clean_prompt(prompt)

# %% [markdown]
# ## Загрузка таблицы

# %%
df_source = pd.read_excel("/content/spirit_all_50.xlsx")
df_source.columns
# Out:
# Index(['Number of hit', 'Text ID', 'Context before', 'Query item',
#        'Context after'],
#       dtype='object')

# %% [markdown]
# ##Тест разовый

# %%
from openai import OpenAI

test_prompt = prompt.format(
    word="spirit",
    text="fret , and all the world repine . Then on , my Lords , and France be fortunate . Exeunt . Alarum . Excursions . Enter Joan de Pucelle . The Regent conquers , and the Frenchmen fly . Now help ye charming spells and periapts , And ye choice spirits that admonish me , And give me signs of future accidents . Thunder . You speedy helpers , that are substitutes Under the Lordly Monarch of the North , Appear , and aid me in this enterprise . Enter Fiends . This speedy and quick appearance argues proof Of your"
)

client = OpenAI(api_key="API ключ")

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[{"role": "user", "content": test_prompt}],
    temperature=0
)

result = response.choices[0].message.content
print(result)

# %% [markdown]
# ## Тест многократный

# %%
from openai import OpenAI
import pandas as pd
from tqdm import tqdm
import time

# Загружаем полный датафрейм
# (например, из файла или как у тебя уже созданный df_source)

# Оставляем только 10 строк
df_test = df_source.iloc[230:240].copy()
df_test['class'] = None  # если вдруг 'class' нет

# Создаём клиента
client = OpenAI(api_key="API ключ")

# Функция get_answer
def get_answer(client, safe_prompt, text, word):
    safe_prompt_to_send = safe_prompt.format(text=text, word=word)
    response = client.chat.completions.create(
        model="gpt-4o-mini-2024-07-18",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": safe_prompt_to_send}
        ],
        temperature=0
    )
    return json.loads(response.choices[0].message.content.strip())["result"]

# Прогоняем только 10 строк
for i, row in tqdm(df_test.iterrows(), total=len(df_test)):
    for _ in range(3):
      try:
          result = get_answer(client, safe_prompt, f"{row['Context before']} {row['Query item']} {row['Context after']}", row['Query item'])
          df_test.at[i, 'class'] = result
          break
      except Exception as e:
          print(f"Ошибка на строке {i}: {e}")
          df_test.at[i, 'class'] = None

# Проверяем результат
print(df_test)

# Сохраняем в Excel
df_test.to_excel('test_result_10.xlsx', index=False)

# %%
df_source
# Out:
#      Number of hit Text ID                                     Context before  \
# 0                1     1H4  I 'll be a Traitor then , when thou art King ....
# 1                2     1H4  with the bloody Payment of your deaths : There...
# 2                3     1H4  field . And thou hast talked Of Sallies , and ...
# 3                4     1H4  Lad , thou sayst true , it is like we shall ha...
# 4                5     1H4  Woman 's Son , Can trace me in the tedious way...
# ..             ...     ...                                                ...
# 379            380      WT  is famous for the Creatures Of prey , that kee...
# 380            381      WT  on shore : And most opportune to her need , I ...
# 381            382      WT  looked upon my Queen 's full eyes , Have taken...
# 382            383      WT  , Remember mine . Stars , Stars , And all eyes...
# 383            384      WT  when first I wooed her . I am ashamed : Does n...
#
# ...

# %% [markdown]
# ##Основной код

# %%
def get_answer(client, safe_prompt, text, word):
    safe_prompt_to_send = safe_prompt.format(text=text, word=word)
    response = client.chat.completions.create(
        model="gpt-4o-mini-2024-07-18",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": safe_prompt_to_send}
        ],
        temperature=0
    )
    return json.loads(response.choices[0].message.content.strip())["result"]

for i, row in tqdm(df_source.iterrows(), total=len(df_source)):
    for _ in range(3):
      try:
          result = get_answer(client, safe_prompt, f"{row['Context before']} {row['Query item']} {row['Context after']}", row['Query item'])
          df_source.at[i, 'class'] = result
          break
      except Exception as e:
          print(f"Ошибка на строке {i}: {e}")
          df_source.at[i, 'class'] = None

# %% [markdown]
# ## Вывод таблицы

# %%
df_source.to_excel("output_2_5_2.xlsx")

# %% [markdown]
# ## Сортировка

# %%
df_sorted = df_source[df_source["class"] == 'II'].copy()

# %%
df_sorted.to_excel("sorted_output_2_5.xlsx")
